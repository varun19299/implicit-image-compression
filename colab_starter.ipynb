# %% [markdown]
# ### Step 0: Change Runtime to GPU

# %%
# Check GPU Type
# !nvidia-smi

# Check python version
# !python --version
# Out:
# Mon Mar  1 07:42:55 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install colabcode

# %%
from colabcode import ColabCode

# %%
## Login to the XYZ.ngrok.io link
ColabCode(port=8888, password="implicit-MLP", mount_drive=True)
# Out:
# Code Server can be accessed on: NgrokTunnel: "http://2a4cfdc84dee.ngrok.io" -> "http://localhost:8888"
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [2021-03-01T07:45:19.507Z] info  code-server 3.7.4 11f53784c58f68e7f4c5b3b8dae9407caa41725b
# [2021-03-01T07:45:19.508Z] info  Using user-data-dir ~/.local/share/code-server
# [2021-03-01T07:45:19.517Z] info  Using config file ~/.config/code-server/config.yaml
# [2021-03-01T07:45:19.518Z] info  HTTP server listening on http://127.0.0.1:8888
# [2021-03-01T07:45:19.518Z] info    - Authentication is enabled
# [2021-03-01T07:45:19.518Z] info      - Using password from $PASSWORD
# [2021-03-01T07:45:19.518Z] info    - Not serving HTTPS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-31d50e27b33d> in <module>()
# ...
